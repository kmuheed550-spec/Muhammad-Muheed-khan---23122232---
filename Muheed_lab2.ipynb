# %% [markdown]
# <a href="https://colab.research.google.com/github/kmuheed550-spec/Muhammad-Muheed-khan---23122232---/blob/main/Muheed_lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai

from google import genai

client = genai.Client("api_key")

print("Gemini Chatbot (type 'exit to quit')\n")
# Chat loop
while True:
    user_input = input("You: ")

    # Exit condition
    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Chatbot: Goodbye 👋")
        break

    # Send input to Gemini
    response = client.models.generate_content(
        model="models/gemini-3.6-flash",  # safer valid model
        contents=user_input,
    )
    # Print response
print("Chatbot:", response.text)
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1195/672262351.py in <cell line: 0>()
#       3 from google import genai
#       4
# ----> 5 client = genai.Client("api_key")
#       6
#       7 print("Gemini Chatbot (type 'exit to quit')\n")
#
# TypeError: Client.__init__() takes 1 positional argument but 2 were given
