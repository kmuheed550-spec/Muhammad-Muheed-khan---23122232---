# %% [markdown]
# <a href="https://colab.research.google.com/github/kmuheed550-spec/Muhammad-Muheed-khan---23122232---/blob/main/M_Muheed_lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai
from google import genai

client = genai.Client(api_key="")

MODEL = "models/gemini-3.6-flash"


def university_agent(user_input):

    prompt = f"""
You are a professional Federal Urdu University (FUUAST) student assistance agent.

You are helping a 6th semester Computer Science student.

Student Information:
- Department: Computer Science
- Semester: 6th
- Teacher: Miss Uzma
- Subject: Artificial Intelligence

Class Schedule:

Wednesday:
- 12:20 - 1:10 : PP - Room 2
- 2:00 - 2:50 : NSC - Room 2
- 2:50 - 3:40 : AI - Lab 1

Thursday:
- 10:40 - 11:30 : NSC - Lab 1
- 11:30 - 12:20 : CC - Lab 1
- 12:20 - 1:10 : PP - Lab 1
- 2:00 - 2:50 : NLP - Lab 1
- 2:50 - 3:40 : AI - Lab 1

Friday:
- 11:30 - 12:20 : CC - Lab 2
- 12:20 - 1:10 : PP - Room 1

Provide answers with clear headings when needed:

1. University Overview
2. Department Information
3. Class Timetable
4. Teachers and Subjects
5. Classroom and Lab Information
6. Student Help

The agent should be able to answer questions such as:
- What is my timetable today?
- When is my AI class?
- Where is my AI class?
- Who teaches Artificial Intelligence?
- What classes do I have on Thursday?
- What time is NLP?
- Which classes are in Lab 1?
- What is my department and semester?

Use the timetable and student information given above when answering.

Do not invent teachers, subjects, timings, rooms, or other university information that has not been provided.

Make answers simple and easy for students to understand.

User request: {user_input}

FUUAST Student Assistant Response:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text


print("FUUAST University Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye")
        break

    try:
        reply = university_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# Requirement already satisfied: google-genai in /usr/local/lib/python3.13/dist-packages (2.12.1)
# Collecting google-genai
#   Downloading google_genai-2.22.0-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (4.14.2)
# Collecting google-auth<3.0.0,>=2.56.0 (from google-auth[requests]<3.0.0,>=2.56.0->google-genai)
#   Downloading google_auth-2.58.0-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in /usr/local/lib/python3.13/dist-packages (from google-genai) (2.13.5)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.13/dist-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.13/dist-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.19)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (50.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.13/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.6.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (3.0)
# Downloading google_genai-2.22.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.7 MB/s eta 0:00:00
# Downloading google_auth-2.58.0-py3-none-any.whl (262 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.4/262.4 kB 11.1 MB/s eta 0:00:00
# Installing collected packages: google-auth, google-genai
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.49.0
#     Uninstalling google-auth-2.49.0:
#       Successfully uninstalled google-auth-2.49.0
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 2.12.1
#     Uninstalling google-genai-2.12.1:
#       Successfully uninstalled google-genai-2.12.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.49.0, but you have google-auth 2.58.0 which is incompatible.
# Successfully installed google-auth-2.58.0 google-genai-2.22.0
# FUUAST University Agent Started (type 'exit' to stop)
#
# You: hi
# WARNING:google_genai.models:Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# Agent:
#  Hello! Welcome to the FUUAST Student Assistance Service.
#
# I am here to help you with your academic schedule, class locations, subject details, and general queries for your **6th semester in the Computer Science Department**.
#
# Here is a quick guide on what I can help you with:
#
# ### 1. Department Information
# * Confirming your current department and semester details.
#
# ### 2. Class Timetable
# * Daily schedules for Wednesday, Thursday, and Friday.
# * Specific class timings (e.g., NLP, AI, CC, PP, NSC).
#
# ### 3. Teachers and Subjects
# * Teacher details (e.g., Miss Uzma for Artificial Intelligence).
#
# ### 4. Classroom and Lab Information
# * Room numbers and lab locations (Room 1, Room 2, Lab 1, Lab 2) for your classes.
#
# ### 5. Student Help
# * Answering specific questions about your daily schedule, subject timings, or room locations.
#
# ---
#
# How can I assist you today? Feel free to ask a question like *"What is my timetable today?"* or *"When is my AI class?"*
#
# You: exit
# Goodbye
